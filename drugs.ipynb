# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_excel("./2022_drugs_perez_dataset.xlsx")
df.head(10)
# Out:
#        Common_name Molecular Weight (g/mol)    pKa Log P Log S  \
# 0         Caffeine                   194.19  14.00 -0.07 -0.97
# 1    Acenocoumarol                    353.3   4.70  1.98  -4.5
# 2    Acetaminophen                   151.16   9.90  0.91  -1.6
# 3   Acetazolamide                     222.3   8.80 -0.26 -2.36
# 4     Acetic acid                     60.05   4.80 -0.17  1.22
# 5     Acepromazine                    326.5   9.30   4.3  -4.5
# 6  Acetylmethadol                     353.5   9.87  4.27  -5.3
# 7   Alphameprodine                    275.4   9.10  3.46  -3.1
# 8     Alphaprodine                   261.36   8.70  3.24  -2.7
# 9       Alprenolol                   249.35   9.60   3.1  -3.1
#
#   Polar Surface Area (Å2) Polarizability (Å3)  HOMO (eV)  LUMO (eV)  \
# 0                   58.44              18.96      -5.769     -1.977
# 1                  109.42               34.35     -6.399     -3.522
# 2                   49.33               15.52     -5.494     -1.646
# 3                  115.04               19.16     -7.010     -3.358
# 4                    37.3                5.34     -6.816     -1.070
# 5                    25.2               37.17     -4.924     -2.529
# 6                   29.54               40.82     -5.163     -1.485
# 7                   29.54                31.7     -5.284     -1.511
# 8                   29.54               29.83     -5.302     -1.501
# 9                   41.49               29.38     -5.694     -1.455
#
#    Ionization Energy (eV)  Electron Affinity (eV)  Electronegativity (eV)  \
# 0                   5.769                   1.977                  3.8730
# 1                   6.399                   3.522                  4.9605
# 2                   5.494                   1.646                  3.5700
# 3                   7.010                   3.358                  5.1840
# 4                   6.816                   1.070                  3.9430
# 5                   4.924                   2.529                  3.7265
# 6                   5.163                   1.485                  3.3240
# 7                   5.284                   1.511                  3.3975
# 8                   5.302                   1.501                  3.4015
# 9                   5.694                   1.455                  3.5745
#
#    Hardness  (eV)  Electrophilicity (eV)       ΔN_Fe  IE (%)
# 0          1.8960                 0.968250  0.824631    92.0
# 1          1.4385                 1.240125  0.708898     NaN
# 2          1.9240                 0.892500  0.891372    85.8
# 3          1.8260                 1.296000  0.497262    93.0
# 4          2.8730                 0.985750  0.532022    92.0
# 5          1.1975                 0.931625  1.366806     NaN
# 6          1.8390                 0.831000  0.999456     NaN
# 7          1.8865                 0.849375  0.954810     NaN
# 8          1.9005                 0.850375  0.946725     NaN
# 9          2.1195                 0.893625  0.808092     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Common_name               260 non-null    object
#  1   Molecular Weight (g/mol)  259 non-null    object
#  2   pKa                       260 non-null    float64
#  3   Log P                     260 non-null    object
#  4   Log S                     256 non-null    object
#  5   Polar Surface Area (Å2)   260 non-null    object
#  6   Polarizability (Å3)       259 non-null    object
#  7   HOMO (eV)                 260 non-null    float64
#  8   LUMO (eV)                 260 non-null    float64
#  9   Ionization Energy (eV)    258 non-null    float64
#  10  Electron Affinity (eV)    258 non-null    float64
#  11  Electronegativity (eV)    258 non-null    float64
#  12  Hardness  (eV)            258 non-null    float64
#  13  Electrophilicity (eV)     260 non-null    float64
#  14   ΔN_Fe                    260 non-null    float64
#  15  IE (%)                    82 non-null     float64
# dtypes: float64(10), object(6)
# memory usage: 32.6+ KB

# %%
df=df.drop(df.columns[0] ,axis=1)
# Remove commas and convert columns to floats
df['Molecular Weight (g/mol)'] = df['Molecular Weight (g/mol)'].replace(',', '', regex=True).astype(float)
df['Log P'] = df['Log P'].replace(',', '', regex=True).astype(float)
df['Log S'] = df['Log S'].replace(',', '', regex=True).astype(float)
df['Polar Surface Area (Å2)'] = df['Polar Surface Area (Å2)'].replace(',', '', regex=True).astype(float)
df['Polarizability (Å3)'] = df['Polarizability (Å3)'].replace(',', '', regex=True).astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Molecular Weight (g/mol)  259 non-null    float64
#  1   pKa                       260 non-null    float64
#  2   Log P                     260 non-null    float64
#  3   Log S                     256 non-null    float64
#  4   Polar Surface Area (Å2)   260 non-null    float64
#  5   Polarizability (Å3)       259 non-null    float64
#  6   HOMO (eV)                 260 non-null    float64
#  7   LUMO (eV)                 260 non-null    float64
#  8   Ionization Energy (eV)    258 non-null    float64
#  9   Electron Affinity (eV)    258 non-null    float64
#  10  Electronegativity (eV)    258 non-null    float64
#  11  Hardness  (eV)            258 non-null    float64
#  12  Electrophilicity (eV)     260 non-null    float64
#  13   ΔN_Fe                    260 non-null    float64
#  14  IE (%)                    82 non-null     float64
# dtypes: float64(15)
# memory usage: 30.6 KB

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 0 to 259
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Molecular Weight (g/mol)  78 non-null     float64
#  1   pKa                       78 non-null     float64
#  2   Log P                     78 non-null     float64
#  3   Log S                     78 non-null     float64
#  4   Polar Surface Area (Å2)   78 non-null     float64
#  5   Polarizability (Å3)       78 non-null     float64
#  6   HOMO (eV)                 78 non-null     float64
#  7   LUMO (eV)                 78 non-null     float64
#  8   Ionization Energy (eV)    78 non-null     float64
#  9   Electron Affinity (eV)    78 non-null     float64
#  10  Electronegativity (eV)    78 non-null     float64
#  11  Hardness  (eV)            78 non-null     float64
#  12  Electrophilicity (eV)     78 non-null     float64
#  13   ΔN_Fe                    78 non-null     float64
#  14  IE (%)                    78 non-null     float64
# dtypes: float64(15)
# memory usage: 9.8 KB

# %%
df.corr()['IE (%)'].sort_values()
# Out:
# Ionization Energy (eV)     -0.227177
# Molecular Weight (g/mol)   -0.156709
# pKa                        -0.095423
# Log S                      -0.081017
# Hardness  (eV)             -0.076029
# Electronegativity (eV)     -0.035239
# Electrophilicity (eV)      -0.035239
# LUMO (eV)                  -0.018368
# Polar Surface Area (Å2)    -0.012571
# Electron Affinity (eV)      0.018368
# Log P                       0.147596
# Polarizability (Å3)         0.171315
# HOMO (eV)                   0.227177
#  ΔN_Fe                      0.271466
# IE (%)                      1.000000
# Name: IE (%), dtype: float64

# %%
# Specify the column you want to analyze for outliers by index
column_index = 0

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)   pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 11                    13714.0  3.38   0.83   -0.4                    63.32
# 226                     822.9  1.70   2.77   -4.3                   220.15
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 11                 13.44     -5.922     -2.122                   5.922
# 226                86.46     -4.855     -2.808                   4.855
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 11                    2.122                  4.0220          1.9000
# 226                   2.808                  3.8315          1.0235
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 11                  1.005500  0.783684    80.0
# 226                 0.957875  1.547875    94.7

# %%
# Specify the column you want to analyze for outliers by index
column_index = 1

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)    pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 256                     75.07  75.07  -3.21   0.87                    63.32
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 256                 6.65     -6.339     -0.773                   6.339
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 256                   0.773                   3.556           2.783
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 256                    0.889  0.618757    80.0

# %%
# Specify the column you want to analyze for outliers by index
column_index = 2

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)  pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 99                      583.6  8.0   -8.2  -1.60                   334.59
# 170                     484.5  7.2   -7.1  -0.72                   282.61
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 99                 56.06     -5.337      0.181                   5.337
# 170                47.57     -5.852      4.514                   5.852
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 99                   -0.181                   2.578           2.759
# 170                  -4.514                   0.669           5.183
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 99                   0.64450  0.801377   88.50
# 170                  0.16725  0.610747   90.96

# %%
# Specify the column you want to analyze for outliers by index
column_index = 3

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)  pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 234                    253.28  5.6   0.89   2.62                    98.22
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 234                24.99     -6.175     -2.495                   6.175
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 234                   2.495                   4.335            1.84
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 234                  1.08375  0.724185    91.6

# %%
# Specify the column you want to analyze for outliers by index
column_index = 4

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)  pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 147                     477.6  8.2   -3.1   -1.6                   199.73
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 147                51.92     -5.503      4.859                   5.503
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 147                  -4.859                   0.322           5.181
#
#      Electrophilicity (eV)      ΔN_Fe  IE (%)
# 147                   0.0805  0.64447   84.65

# %%
# Specify the column you want to analyze for outliers by index
column_index = 5

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)  pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 224                     608.7  6.6   3.53   -4.7                   117.78
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 224                66.06     -4.905     -2.329                   4.905
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 224                   2.329                   3.617           1.288
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 224                  0.90425  1.313276    94.0

# %%
# Specify the column you want to analyze for outliers by index
column_index = 6

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)  pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 259                    250.28  6.5  -0.09  -3.51                    97.97
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 259                24.39     -4.165     -2.126                   4.165
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 259                   2.126                  3.1455          1.0195
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 259                 0.786375  1.890387    94.0

# %%
# Specify the column you want to analyze for outliers by index
column_index = 7

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)   pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 90                    105.140   8.9  -1.43   0.65                    52.49
# 91                     73.140  11.0   0.76   0.54                    12.03
# 120                    45.080  10.7  -0.13   0.90                    26.00
# 250                    60.056   0.2  -2.11   0.96                    69.11
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 90                 11.63     -5.798      6.520                   5.798
# 91                  9.72     -5.505      6.840                   5.505
# 120                 5.75     -6.042      7.222                   6.042
# 250                 5.10     -6.050      0.332                   6.050
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 90                   -6.520                 -0.3610          6.1590
# 91                   -6.840                 -0.6675          6.1725
# 120                  -7.222                 -0.5900          6.6320
# 250                  -0.332                  2.8590          3.1910
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 90                 -0.090250  0.597581   88.70
# 91                 -0.166875  0.621102   80.61
# 120                -0.147500  0.572226   96.40
# 250                 0.714750  0.648856   94.06

# %%
# Specify the column you want to analyze for outliers by index
column_index = 8

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
# Empty DataFrame
# Columns: [Molecular Weight (g/mol), pKa, Log P, Log S, Polar Surface Area (Å2), Polarizability (Å3), HOMO (eV), LUMO (eV), Ionization Energy (eV), Electron Affinity (eV), Electronegativity (eV), Hardness  (eV), Electrophilicity (eV)  ,  ΔN_Fe, IE (%)]
# Index: []

# %%
# Specify the column you want to analyze for outliers by index
column_index = 9

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)    pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 159                  111.1451  14.46  -0.70   0.18                    54.70
# 161                   68.0800   7.00  -0.08   0.90                    28.68
# 162                   68.0800   7.00  -0.08   0.90                    28.68
# 207                  238.1600   7.20  -0.47  -2.80                   118.05
# 225                  376.4000  10.20  -1.46  -3.68                   155.05
# 227                  183.1900   1.60   0.45  -1.40                    63.24
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 159                12.08     -5.549     -0.315                   5.549
# 161                 6.56     -5.805     -0.375                   5.805
# 162                 6.56     -5.805     -0.375                   5.805
# 207                20.49     -6.456     -3.951                   6.456
# 225                37.50     -6.119     -4.021                   6.119
# 227                16.02     -7.116     -3.929                   7.116
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 159                   0.315                  2.9320          2.6170
# 161                   0.375                  3.0900          2.7150
# 162                   0.375                  3.0900          2.7150
# 207                   3.951                  5.2035          1.2525
# 225                   4.021                  5.0700          1.0490
# 227                   3.929                  5.5225          1.5935
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 159                 0.733000  0.777226   95.60
# 161                 0.772500  0.720074   89.00
# 162                 0.772500  0.720074   89.00
# 207                 1.300875  0.717166   97.60
# 225                 1.267500  0.919924   83.90
# 227                 1.380625  0.463602   83.78

# %%
# Specify the column you want to analyze for outliers by index
column_index = 10

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
# Empty DataFrame
# Columns: [Molecular Weight (g/mol), pKa, Log P, Log S, Polar Surface Area (Å2), Polarizability (Å3), HOMO (eV), LUMO (eV), Ionization Energy (eV), Electron Affinity (eV), Electronegativity (eV), Hardness  (eV), Electrophilicity (eV)  ,  ΔN_Fe, IE (%)]
# Index: []

# %%
# Specify the column you want to analyze for outliers by index
column_index = 11

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)   pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 4                       60.05  4.80  -0.17   1.22                     37.3
# 104                    444.40  3.09  -0.70  -2.80                    182.0
# 105                    444.40  3.09  -0.70  -2.80                    182.0
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 4                   5.34     -6.816     -1.070                   6.816
# 104                43.65     -5.693     -3.454                   5.693
# 105                43.65     -5.693     -3.454                   5.693
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 4                     1.070                  3.9430          2.8730
# 104                   3.454                  4.5735          1.1195
# 105                   3.454                  4.5735          1.1195
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 4                   0.985750  0.532022    92.0
# 104                 1.143375  1.083743    95.9
# 105                 1.143375  1.083743    95.9

# %%
# Specify the column you want to analyze for outliers by index
column_index = 12

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
# Empty DataFrame
# Columns: [Molecular Weight (g/mol), pKa, Log P, Log S, Polar Surface Area (Å2), Polarizability (Å3), HOMO (eV), LUMO (eV), Ionization Energy (eV), Electron Affinity (eV), Electronegativity (eV), Hardness  (eV), Electrophilicity (eV)  ,  ΔN_Fe, IE (%)]
# Index: []

# %%
# Specify the column you want to analyze for outliers by index
column_index = 13

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
# Empty DataFrame
# Columns: [Molecular Weight (g/mol), pKa, Log P, Log S, Polar Surface Area (Å2), Polarizability (Å3), HOMO (eV), LUMO (eV), Ionization Energy (eV), Electron Affinity (eV), Electronegativity (eV), Hardness  (eV), Electrophilicity (eV)  ,  ΔN_Fe, IE (%)]
# Index: []

# %%
# Specify the column you want to analyze for outliers by index
column_index = 14

# Check if the specified column contains numeric data
column_name = df.columns[column_index]

# Method 2: IQR (Interquartile Range) Method
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers based on the bounds
outliers_iqr = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

print("\nOutliers using IQR Method:")
print(outliers_iqr)

print("\n")

# Create a scatter plot to visualize outliers
plt.figure(figsize=(8, 6))
plt.scatter(df.index, df[column_name], label='Data Points', alpha=0.5)
plt.scatter(outliers_iqr.index, outliers_iqr[column_name], color='red', label='Outliers (IQR)', alpha=0.7)
plt.title(f'Scatter Plot with Outliers for {column_name}')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.legend()
plt.show()

df = df.drop(outliers_iqr.index) # data outlier drop
# Out:
# Outliers using IQR Method:
#      Molecular Weight (g/mol)  pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 230                    214.25  2.8  -0.52   -2.4                   122.06
#
#      Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Ionization Energy (eV)  \
# 230                20.38     -5.926     -2.103                   5.926
#
#      Electron Affinity (eV)  Electronegativity (eV)  Hardness  (eV)  \
# 230                   2.103                  4.0145          1.9115
#
#      Electrophilicity (eV)       ΔN_Fe  IE (%)
# 230                 1.003625  0.780931    67.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 0 to 254
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Molecular Weight (g/mol)  55 non-null     float64
#  1   pKa                       55 non-null     float64
#  2   Log P                     55 non-null     float64
#  3   Log S                     55 non-null     float64
#  4   Polar Surface Area (Å2)   55 non-null     float64
#  5   Polarizability (Å3)       55 non-null     float64
#  6   HOMO (eV)                 55 non-null     float64
#  7   LUMO (eV)                 55 non-null     float64
#  8   Ionization Energy (eV)    55 non-null     float64
#  9   Electron Affinity (eV)    55 non-null     float64
#  10  Electronegativity (eV)    55 non-null     float64
#  11  Hardness  (eV)            55 non-null     float64
#  12  Electrophilicity (eV)     55 non-null     float64
#  13   ΔN_Fe                    55 non-null     float64
#  14  IE (%)                    55 non-null     float64
# dtypes: float64(15)
# memory usage: 6.9 KB

# %%
df.corr()['IE (%)'].sort_values()
# Out:
# Electronegativity (eV)     -0.255704
# Electrophilicity (eV)      -0.255704
# Ionization Energy (eV)     -0.249062
# Electron Affinity (eV)     -0.206688
# Polar Surface Area (Å2)    -0.120141
# Log S                      -0.054841
# Hardness  (eV)             -0.020473
# Molecular Weight (g/mol)    0.055121
# Polarizability (Å3)         0.145229
# Log P                       0.169856
# pKa                         0.201459
# LUMO (eV)                   0.206688
# HOMO (eV)                   0.249062
#  ΔN_Fe                      0.273050
# IE (%)                      1.000000
# Name: IE (%), dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool), cmap=sns.diverging_palette(240, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# <Axes: >

# %%
X=df.iloc[:, 0:14]
y=df.iloc[:,14]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#model linear
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import HuberRegressor
from sklearn.linear_model import BayesianRidge

#model nonlinear
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

#model ensemble
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.kernel_ridge import KernelRidge

from datetime import datetime
from sklearn.metrics import r2_score, mean_squared_error

from sklearn.neural_network import MLPRegressor

# %%
linear_reg = LinearRegression()
start = datetime.now()
linear_reg.fit(X_train, y_train)
pred = linear_reg.predict(X_test)
stop = datetime.now()
delta = stop - start

print('Linear Regression\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

linear_Reg = ('Linear Regression', r2, err, seconds)
# Out:
# Linear Regression
#
# R2:  -1.0029693854551032
# Root Mean Squared Error:  8.186495941481015
# Time to compute:  0.008306 seconds

# %%
svr_linear = SVR(kernel='linear')
start = datetime.now()
svr_linear.fit(X_train, y_train)
pred = svr_linear.predict(X_test)
stop = datetime.now()
delta = stop - start

print('SVR Linear Regression\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')


# Storing results
svr_linear_reg = ('SVR Linear Regression',  r2, err, seconds)
# Out:
# SVR Linear Regression
#
# R2:  -0.29196678016574906
# Root Mean Squared Error:  6.574860892272596
# Time to compute:  0.002 seconds

# %%
from sklearn.linear_model import ElasticNet
elastic = ElasticNet(alpha=0.5, l1_ratio=0.5)
start = datetime.now()
elastic.fit(X_train, y_train)
pred = elastic.predict(X_test)
stop = datetime.now()
delta = stop - start

print('Elastic Net Regression\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

# Storing results
ElasticNet = ('Elastic Net Regression',  r2, err, seconds)
# Out:
# Elastic Net Regression
#
# R2:  -0.294147895893784
# Root Mean Squared Error:  6.580408436278886
# Time to compute:  0.002998 seconds

# %%
Hreg= HuberRegressor(epsilon=1.0)
start = datetime.now()
Hreg.fit(X_train, y_train)
pred = Hreg.predict(X_test)
stop = datetime.now()
delta = stop - start

print('Hubber Regressor\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')


# Storing results
HuberRegressor = ('Hubber Regressor', r2, err, seconds)
# Out:
# Hubber Regressor
#
# R2:  -0.8875192568363806
# Root Mean Squared Error:  7.947061807750388
# Time to compute:  0.035517 seconds
# c:\Users\Darnell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_huber.py:342: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
svr_non_linear = SVR(kernel='rbf')
start = datetime.now()
svr_non_linear.fit(X_train, y_train)
pred = svr_non_linear.predict(X_test)
stop = datetime.now()
delta = stop - start

print('SVR Non Linear Regression\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

# Storing results
svr_Non_linear_reg = ('SVR Non Linear Regression',  r2, err, seconds)
# Out:
# SVR Non Linear Regression
#
# R2:  -0.5006576037244461
# Root Mean Squared Error:  7.086009034984742
# Time to compute:  0.001 seconds

# %%
randomforest = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)
start = datetime.now()
randomforest.fit(X_train, y_train)
pred = randomforest.predict(X_test)
stop = datetime.now()
delta = stop - start

print('Random Forest Regressor\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

# Storing results
Randomforest = ('Random Forest Regressor', r2, err, seconds)
# Out:
# Random Forest Regressor
#
# R2:  -0.9699499466895711
# Root Mean Squared Error:  8.118737335735569
# Time to compute:  0.011997 seconds

# %%
DecissionTree = DecisionTreeRegressor(max_depth=5)
start = datetime.now()
DecissionTree.fit(X_train, y_train)
pred = DecissionTree.predict(X_test)
stop = datetime.now()
delta = stop - start

print('Decission Tree Regressor\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

# Storing results
DecissionTree_Regressor = ('Decission Tree Regressor', r2, err, seconds)
# Out:
# Decission Tree Regressor
#
# R2:  -1.1313309371381362
# Root Mean Squared Error:  8.44474110407269
# Time to compute:  0.001001 seconds

# %%
KNN = KNeighborsRegressor()
start = datetime.now()
KNN.fit(X_train, y_train)
pred = KNN.predict(X_test)
stop = datetime.now()
delta = stop - start

print('KNN Regressor\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

# Storing results
KNN_Regressor = ('KNN Regressor', r2, err, seconds)
# Out:
# KNN Regressor
#
# R2:  -0.4491206489402484
# Root Mean Squared Error:  6.963268916249037
# Time to compute:  0.003001 seconds

# %%
XGB = XGBRegressor()
start = datetime.now()
XGB.fit(X_train, y_train)
pred = XGB.predict(X_test)
stop = datetime.now()
delta = stop - start

print('XGB Regressor\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

# Storing results
XGB_Regressor = ('XGB Regressor', r2, err, seconds)
# Out:
# XGB Regressor
#
# R2:  -0.2750187377046234
# Root Mean Squared Error:  6.531593960584533
# Time to compute:  0.103056 seconds

# %%
ExtraTree =  ExtraTreesRegressor(n_estimators=100, random_state=0)
start = datetime.now()
ExtraTree.fit(X_train, y_train)
pred = ExtraTree.predict(X_test)
stop = datetime.now()
delta = stop - start

print('Extra Tree Regressor\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')

# Storing results
extratreee = ('Extra Tree Regressor', r2, err, seconds)
# Out:
# Extra Tree Regressor
#
# R2:  -0.6448181048437585
# Root Mean Squared Error:  7.418563766664434
# Time to compute:  0.053795 seconds

# %%
# Instantiate MLPRegressor
Mlp = MLPRegressor(random_state=1, max_iter=500)
start = datetime.now()
Mlp.fit(X_train, y_train)
pred = Mlp.predict(X_test)
stop = datetime.now()
delta = stop - start

print('MLP Regressor\n')
r2 = r2_score(y_test, pred)
print('R2: ', r2)
err = np.sqrt(mean_squared_error(y_test, pred))
print('Root Mean Squared Error: ', err)
seconds = delta.seconds + delta.microseconds/1E6
print('Time to compute: ', seconds, 'seconds')



# Storing results
Mlp_results = ('MLP Regressor', r2, err, seconds)
# Out:
# MLP Regressor
#
# R2:  -17.134779947944416
# Root Mean Squared Error:  24.632984878075863
# Time to compute:  0.106664 seconds
# c:\Users\Darnell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
df_results = pd.DataFrame([linear_Reg,svr_linear_reg,ElasticNet,HuberRegressor,svr_Non_linear_reg,Randomforest,DecissionTree_Regressor,KNN_Regressor,XGB_Regressor,extratreee,Mlp_results]
                          , columns=['model', 'R2','Rmse','Time to Computed'])
df_results.sort_values('Rmse',ascending=True)
# Out:
#                         model         R2       Rmse  Time to Computed
# 8               XGB Regressor  -0.275019   6.531594          0.103056
# 1       SVR Linear Regression  -0.291967   6.574861          0.002000
# 2      Elastic Net Regression  -0.294148   6.580408          0.002998
# 7               KNN Regressor  -0.449121   6.963269          0.003001
# 4   SVR Non Linear Regression  -0.500658   7.086009          0.001000
# 9        Extra Tree Regressor  -0.644818   7.418564          0.053795
# 3            Hubber Regressor  -0.887519   7.947062          0.035517
# 5     Random Forest Regressor  -0.969950   8.118737          0.011997
# 0           Linear Regression  -1.002969   8.186496          0.008306
# 6    Decission Tree Regressor  -1.131331   8.444741          0.001001
# 10              MLP Regressor -17.134780  24.632985          0.106664
